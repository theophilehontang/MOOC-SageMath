# %%
x=var('x')

# %%
f(x)=exp(-x)

# %%
def un(f,a,n):
    liste=[]
    for k in range(n):
        liste.append(a)
        a=f(a)
    return liste

# %%
un(f,-1,4)
# Out:
# [-1, e, e^(-e), e^(-e^(-e))]

# %%
def points(f,a,n):
    begin=[(un(f,a,n)[0],0)]
    for k in range(n-1):
        begin.append((un(f,a,n)[k],un(f,a,n)[k+1]))
        begin.append((un(f,a,n)[k+1],un(f,a,n)[k+1]))
    return begin

# %%
points(f,-1,4)
# Out:
# [(-1, 0),
#  (-1, e),
#  (e, e),
#  (e, e^(-e)),
#  (e^(-e), e^(-e)),
#  (e^(-e), e^(-e^(-e))),
#  (e^(-e^(-e)), e^(-e^(-e)))]

# %%
def dessin(f,a,n):
    g=plot(f,(x,-1,3))+plot(x,(x,-1,3))+line(points(f,a,n))
    g.show()

# %%
dessin(f,-1,10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
range(6)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
premiers=[k for k in range(20) if is_prime(k)]

# %%
doubles=[2*p+1 for p in range(30) if is_prime(p)]

# %%
doubles[0:10]
# Out:
# [5, 7, 11, 15, 23, 27, 35, 39, 47, 59]

# %%
[premiers[k]*k for k in range(6)]
# Out:
# [0, 3, 10, 21, 44, 65]

# %%
premiers[0]
# Out:
# 2

# %%
r=var('r')

# %%
g(x)=r*x*(1-x)

# %%
def vn(f,a,n):
    liste=[]
    for k in range(n):
        liste.append(a)
        a=f(a)
    return liste

# %%
def points2(f,a,n):
    begin=[(vn(f,a,n)[0],0)]
    for k in range(n-1):
        begin.append((vn(f,a,n)[k],vn(f,a,n)[k+1]))
        begin.append((vn(f,a,n)[k+1],vn(f,a,n)[k+1]))
    return begin

# %%
def dessin2(f,a,n):
    g=plot(f,(x,0,1))+plot(x,(x,0,1))+line(points(f,a,n))
    g.show()

# %%
r=4

# %%
dessin2(g,0.123,100)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
dessin2(g,0.123,100)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
dessin2(g,0.123,100)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
F(x,r)=r*x*(1-x)

# %%
def bifurcation(F,u0):
    Nmin=100
    Nmax=200
    epsilon=0.05
    r=2.5
    point=[]
    while r<=4 :
        u=vn(F(x,r),u0,Nmax)
        for k in range(Nmin,Nmax):
            point=point+[(u[k],r)]
        r=r+epsilon
    G=points(point,1,2)
    G.show()

# %%
bifurcation(F,0.5)
# Out:
# /home/sage/sage-8.0/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:8: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-d469963eb8eb> in <module>()
# ----> 1 bifurcation(F,RealNumber('0.5'))
#
# <ipython-input-93-e85504510f96> in bifurcation(F, u0)
#      10             point=point+[(u[k],r)]
#      11         r=r+epsilon
# ---> 12     G=points(point,Integer(1),Integer(2))
#      13     G.show()
#
# <ipython-input-56-6b6dff8b3b97> in points(f, a, n)
#       1 def points(f,a,n):
# ----> 2     begin=[(un(f,a,n)[Integer(0)],Integer(0))]
#       3     for k in range(n-Integer(1)):
# ...

# %%
points?
