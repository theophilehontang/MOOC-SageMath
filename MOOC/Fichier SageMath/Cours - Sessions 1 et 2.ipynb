# %%
1+2*3^4
# Out:
# 163

# %%
22/33
# Out:
# 2/3

# %%
cos(pi/6)
# Out:
# 1/2*sqrt(3)

# %%
(1-i)^8
# Out:
# 16

# %%
f(x)=exp(x)*sin(x)
show(f)
# Out:
# x |--> e^x*sin(x)

# %%
g(x)=taylor(f(x),x,0,1)
show(g)
# Out:
# x |--> x

# %%
h(x)=taylor(f(x),x,0,2)
show(h)
# Out:
# x |--> x^2 + x

# %%
k(x)=taylor(f(x),x,0,3)
show(k)
# Out:
# x |--> 1/3*x^3 + x^2 + x

# %%
g1=plot(g,(0,1))
g2=plot(h,(0,1))
g3=plot(k,(0,1))
g1+g2+g3
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
var('t')
var('x,y')
# Out:
# (x, y)

# %%
parametric_plot((cos(3*t),sin(4*t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(cos(x*y),(x,-4,4),(y,-4,4))
# Out:
# Graphics3d Object

# %%
show((x^4-x-1).roots())
# Out:
# [(-1/2*sqrt(1/3)*sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) - 1/2*sqrt(-(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3) - 6*sqrt(1/3)/sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) + 4/3/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)),
#   1),
#  (-1/2*sqrt(1/3)*sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) + 1/2*sqrt(-(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3) - 6*sqrt(1/3)/sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) + 4/3/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)),
#   1),
#  (1/2*sqrt(1/3)*sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) - 1/2*sqrt(-(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3) + 6*sqrt(1/3)/sqrt((3*(1/18*sqrt(283)*sqrt(3) + 1/2)^(2/3) - 4)/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)) + 4/3/(1/18*sqrt(283)*sqrt(3) + 1/2)^(1/3)),
#   1),
# ...

# %%
2^10-1024
# Out:
# 0

# %%
expand((x+1)^2-x^2-2*x-1)
# Out:
# 0

# %%
f(x)=cos(x)^2+sin(x)^2-1
f.simplify_trig()
# Out:
# x |--> 0

# %%
for n in range(8):
    print(n,factor(2^(2^n)+1))
# Out:
# (0, 3)
# (1, 5)
# (2, 17)
# (3, 257)
# (4, 65537)
# (5, 641 * 6700417)
# (6, 274177 * 67280421310721)
# (7, 59649589127497217 * 5704689200685129054721)

# %%
for P in {True,False}:
    for Q in {True,False}:
        for R in {True,False}:
            print(not((not(P and Q) and (Q or R) and (P and not(R)))))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True

# %%
var('a,b,c')
# Out:
# (a, b, c)

# %%
def P(X):
    return((X-a)*(X-b)/((c-b)*(c-a))+(X-b)*(X-c)/((a-b)*(a-c))+(X-a)*(X-c)/((b-a)*(b-c))-1)

# %%
simplify_rational(P(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8fdc26fbabf0> in <module>()
# ----> 1 simplify_rational(P(X))
#
# NameError: name 'simplify_rational' is not defined

# %%
var('X')
# Out:
# X
